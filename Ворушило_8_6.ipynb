# %% [markdown]
# Завдання 1

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import os

# %%
#1. Завантажити датасет
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
#2. Роздрукувати 10 зображень.
plt.figure(figsize=(10,10))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
#3. Підготовувати дані, побудувати архітектуру.
#4. Вивести архітектуру моделі.
train_images = train_images / 255.0
test_images = test_images / 255.0

model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(512, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │         401,920 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 567,434 (2.16 MB)
#  Trainable params: 567,434 (2.16 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
#5. Використати ранню зупинку і зменшення швидкості для запобіганню перенавчанню.
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2)

history = model.fit(train_images, train_labels, epochs=50,
                    validation_data=(test_images, test_labels),
                    callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.7863 - loss: 0.5926 - val_accuracy: 0.8420 - val_loss: 0.4680 - learning_rate: 0.0010
# Epoch 2/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 41s 11ms/step - accuracy: 0.8609 - loss: 0.3752 - val_accuracy: 0.8667 - val_loss: 0.3678 - learning_rate: 0.0010
# Epoch 3/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.8811 - loss: 0.3259 - val_accuracy: 0.8703 - val_loss: 0.3546 - learning_rate: 0.0010
# Epoch 4/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.8861 - loss: 0.3025 - val_accuracy: 0.8728 - val_loss: 0.3473 - learning_rate: 0.0010
# Epoch 5/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.8925 - loss: 0.2870 - val_accuracy: 0.8777 - val_loss: 0.3312 - learning_rate: 0.0010
# Epoch 6/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.8968 - loss: 0.2707 - val_accuracy: 0.8751 - val_loss: 0.3545 - learning_rate: 0.0010
# Epoch 7/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 41s 11ms/step - accuracy: 0.9011 - loss: 0.2572 - val_accuracy: 0.8823 - val_loss: 0.3269 - learning_rate: 0.0010
# Epoch 8/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.9060 - loss: 0.2476 - val_accuracy: 0.8854 - val_loss: 0.3268 - learning_rate: 0.0010
# Epoch 9/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.9133 - loss: 0.2278 - val_accuracy: 0.8865 - val_loss: 0.3364 - learning_rate: 0.0010
# Epoch 10/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 41s 12ms/step - accuracy: 0.9271 - loss: 0.1896 - val_accuracy: 0.8948 - val_loss: 0.3206 - learning_rate: 2.0000e-04
# Epoch 11/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 39s 12ms/step - accuracy: 0.9338 - loss: 0.1716 - val_accuracy: 0.8976 - val_loss: 0.3201 - learning_rate: 2.0000e-04
# Epoch 12/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - accuracy: 0.9382 - loss: 0.1640 - val_accuracy: 0.8973 - val_loss: 0.3304 - learning_rate: 2.0000e-04
# Epoch 13/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 41s 11ms/step - accuracy: 0.9403 - loss: 0.1554 - val_accuracy: 0.8954 - val_loss: 0.3486 - learning_rate: 2.0000e-04
# Epoch 14/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.9452 - loss: 0.1433 - val_accuracy: 0.9004 - val_loss: 0.3455 - learning_rate: 4.0000e-05

# %%
#6. Зберегти модель на гугл диск
from google.colab import drive
drive.mount('/content/drive')
model.save('/content/drive/MyDrive/fashion_mnist_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Mounted at /content/drive

# %%
#7. Побудувати графіки функції втрат і точності для тренувальних і тестових даних
plt.figure(figsize=(9, 3))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('Витрати')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Test Accuracy')
plt.title('Точності')
plt.grid(True)
plt.legend()

plt.show()

# %%
#8. Вивести класифікаційний звіт.
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
predictions = model.predict(test_images)

predicted_labels = np.argmax(predictions, axis=1)

print(classification_report(test_labels, predicted_labels, target_names=class_names))
# Out:
# 313/313 - 1s - 5ms/step - accuracy: 0.8976 - loss: 0.3201
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.83      0.88      0.86      1000
#      Trouser       0.99      0.98      0.98      1000
#     Pullover       0.84      0.79      0.81      1000
#        Dress       0.89      0.91      0.90      1000
#         Coat       0.79      0.85      0.82      1000
#       Sandal       0.98      0.97      0.97      1000
#        Shirt       0.76      0.69      0.72      1000
#      Sneaker       0.94      0.98      0.96      1000
#          Bag       0.98      0.98      0.98      1000
#   Ankle boot       0.97      0.95      0.96      1000
#
#     accuracy                           0.90     10000
#    macro avg       0.90      0.90      0.90     10000
# weighted avg       0.90      0.90      0.90     10000

# %%
#9. Результати розпізнавання із прогнозованим і справжнім класом
plt.figure(figsize=(10, 10))
for i in range(10):
    plt.subplot(1, 10, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(test_images[i], cmap=plt.cm.binary)
    plt.xlabel(f"Pred: {class_names[predicted_labels[i]]}\nTrue: {class_names[test_labels[i]]}")
plt.show()

# %% [markdown]
# Завдання 2
# Побудувати нейронну мережу, аналогічну завданню 1 для датасета fashion
# mnist

# %%
# !pip install keras-tuner -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 5.1 MB/s eta 0:00:00

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense, Dropout, Flatten, BatchNormalization
from keras.regularizers import l2
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from kerastuner.tuners import RandomSearch
# Out:
# <ipython-input-13-5270575026c6>:6: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import RandomSearch

# %%
fashion_mnist = keras.datasets.fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

print("x_train original shape", x_train.shape)
print("y_train original shape", y_train.shape)

x_train = x_train / 255.0
x_test = x_test / 255.0
# Out:
# x_train original shape (60000, 28, 28)
# y_train original shape (60000,)

# %%
def build_model(hp):
    model = keras.Sequential()
    model.add(Flatten(input_shape=(28, 28)))

    for i in range(hp.Int('num_layers', 1, 4)):
        model.add(Dense(units=hp.Int('units_' + str(i),
                                     min_value=32,
                                     max_value=512,
                                     step=32),
                        activation='relu',
                        kernel_regularizer=l2(0.001)))
        model.add(BatchNormalization())
        model.add(Dropout(0.3))

    model.add(Dense(10, activation='softmax'))

    model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    return model

tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=3,
    executions_per_trial=1,
    directory='tuner_logs',
    project_name='fashion_mnist_classification'
)
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)
tuner.search(x_train, y_train, epochs=50, validation_data=(x_test, y_test), callbacks=[early_stopping, reduce_lr])
best_model = tuner.get_best_models(num_models=1)[0]
best_model.summary()
best_model.fit(x_train, y_train, epochs=50, validation_data=(x_test, y_test), callbacks=[early_stopping, reduce_lr])
test_loss, test_acc = best_model.evaluate(x_test, y_test)

print('Test accuracy:', test_acc)
print('Test loss:', test_loss)
# Out:
# Trial 3 Complete [00h 13m 52s]
# val_accuracy: 0.8884000182151794
#
# Best val_accuracy So Far: 0.888700008392334
# Total elapsed time: 00h 51m 12s
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py:576: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 480)                 │         376,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 480)                 │           1,920 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 480)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           4,810 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 383,530 (1.46 MB)
#  Trainable params: 382,570 (1.46 MB)
#  Non-trainable params: 960 (3.75 KB)
# Epoch 1/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.8316 - loss: 0.5199 - val_accuracy: 0.8416 - val_loss: 0.5017 - learning_rate: 0.0010
# Epoch 2/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8344 - loss: 0.5326 - val_accuracy: 0.8458 - val_loss: 0.5060 - learning_rate: 0.0010
# Epoch 3/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.8349 - loss: 0.5335 - val_accuracy: 0.8249 - val_loss: 0.5573 - learning_rate: 0.0010
# Epoch 4/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.8322 - loss: 0.5430 - val_accuracy: 0.8350 - val_loss: 0.5412 - learning_rate: 0.0010
# Epoch 5/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8435 - loss: 0.5035 - val_accuracy: 0.8479 - val_loss: 0.4774 - learning_rate: 5.0000e-04
# Epoch 6/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8500 - loss: 0.4766 - val_accuracy: 0.8450 - val_loss: 0.4928 - learning_rate: 5.0000e-04
# Epoch 7/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.8509 - loss: 0.4704 - val_accuracy: 0.8560 - val_loss: 0.4593 - learning_rate: 5.0000e-04
# Epoch 8/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.8503 - loss: 0.4693 - val_accuracy: 0.8485 - val_loss: 0.4832 - learning_rate: 5.0000e-04
# Epoch 9/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - accuracy: 0.8525 - loss: 0.4646 - val_accuracy: 0.8475 - val_loss: 0.4778 - learning_rate: 5.0000e-04
# Epoch 10/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8530 - loss: 0.4639 - val_accuracy: 0.8568 - val_loss: 0.4620 - learning_rate: 5.0000e-04
# Epoch 11/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8592 - loss: 0.4418 - val_accuracy: 0.8566 - val_loss: 0.4493 - learning_rate: 2.5000e-04
# Epoch 12/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.8679 - loss: 0.4154 - val_accuracy: 0.8571 - val_loss: 0.4326 - learning_rate: 2.5000e-04
# Epoch 13/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.8666 - loss: 0.4185 - val_accuracy: 0.8502 - val_loss: 0.4536 - learning_rate: 2.5000e-04
# Epoch 14/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8695 - loss: 0.4074 - val_accuracy: 0.8673 - val_loss: 0.4245 - learning_rate: 2.5000e-04
# Epoch 15/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.8686 - loss: 0.4015 - val_accuracy: 0.8570 - val_loss: 0.4290 - learning_rate: 2.5000e-04
# Epoch 16/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8730 - loss: 0.3983 - val_accuracy: 0.8621 - val_loss: 0.4183 - learning_rate: 2.5000e-04
# Epoch 17/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.8720 - loss: 0.3963 - val_accuracy: 0.8695 - val_loss: 0.4139 - learning_rate: 2.5000e-04
# Epoch 18/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.8716 - loss: 0.3933 - val_accuracy: 0.8574 - val_loss: 0.4429 - learning_rate: 2.5000e-04
# Epoch 19/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - accuracy: 0.8706 - loss: 0.3928 - val_accuracy: 0.8644 - val_loss: 0.4183 - learning_rate: 2.5000e-04
# Epoch 20/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.8722 - loss: 0.3962 - val_accuracy: 0.8658 - val_loss: 0.4200 - learning_rate: 2.5000e-04
# Epoch 21/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8744 - loss: 0.3805 - val_accuracy: 0.8707 - val_loss: 0.3955 - learning_rate: 1.2500e-04
# Epoch 22/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.8833 - loss: 0.3606 - val_accuracy: 0.8745 - val_loss: 0.3944 - learning_rate: 1.2500e-04
# Epoch 23/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.8856 - loss: 0.3537 - val_accuracy: 0.8795 - val_loss: 0.3844 - learning_rate: 1.2500e-04
# Epoch 24/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8847 - loss: 0.3556 - val_accuracy: 0.8756 - val_loss: 0.3849 - learning_rate: 1.2500e-04
# Epoch 25/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - accuracy: 0.8870 - loss: 0.3448 - val_accuracy: 0.8767 - val_loss: 0.3835 - learning_rate: 1.2500e-04
# Epoch 26/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - accuracy: 0.8869 - loss: 0.3440 - val_accuracy: 0.8741 - val_loss: 0.3887 - learning_rate: 1.2500e-04
# Epoch 27/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 9ms/step - accuracy: 0.8880 - loss: 0.3450 - val_accuracy: 0.8734 - val_loss: 0.3890 - learning_rate: 1.2500e-04
# Epoch 28/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.8866 - loss: 0.3419 - val_accuracy: 0.8772 - val_loss: 0.3793 - learning_rate: 1.2500e-04
# Epoch 29/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 19s 9ms/step - accuracy: 0.8893 - loss: 0.3420 - val_accuracy: 0.8769 - val_loss: 0.3782 - learning_rate: 1.2500e-04
# Epoch 30/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8896 - loss: 0.3354 - val_accuracy: 0.8766 - val_loss: 0.3813 - learning_rate: 1.2500e-04
# Epoch 31/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 22s 11ms/step - accuracy: 0.8874 - loss: 0.3404 - val_accuracy: 0.8745 - val_loss: 0.3872 - learning_rate: 1.2500e-04
# Epoch 32/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.8895 - loss: 0.3354 - val_accuracy: 0.8726 - val_loss: 0.3844 - learning_rate: 1.2500e-04
# Epoch 33/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.8941 - loss: 0.3197 - val_accuracy: 0.8793 - val_loss: 0.3733 - learning_rate: 6.2500e-05
# Epoch 34/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.8951 - loss: 0.3192 - val_accuracy: 0.8838 - val_loss: 0.3657 - learning_rate: 6.2500e-05
# Epoch 35/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.8963 - loss: 0.3110 - val_accuracy: 0.8830 - val_loss: 0.3654 - learning_rate: 6.2500e-05
# Epoch 36/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.8995 - loss: 0.3094 - val_accuracy: 0.8822 - val_loss: 0.3588 - learning_rate: 6.2500e-05
# Epoch 37/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.8977 - loss: 0.3069 - val_accuracy: 0.8844 - val_loss: 0.3598 - learning_rate: 6.2500e-05
# Epoch 38/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.9003 - loss: 0.3024 - val_accuracy: 0.8830 - val_loss: 0.3635 - learning_rate: 6.2500e-05
# Epoch 39/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.9023 - loss: 0.2965 - val_accuracy: 0.8819 - val_loss: 0.3653 - learning_rate: 6.2500e-05
# Epoch 40/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - accuracy: 0.9002 - loss: 0.2993 - val_accuracy: 0.8862 - val_loss: 0.3575 - learning_rate: 3.1250e-05
# Epoch 41/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.9057 - loss: 0.2902 - val_accuracy: 0.8879 - val_loss: 0.3537 - learning_rate: 3.1250e-05
# Epoch 42/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.9049 - loss: 0.2869 - val_accuracy: 0.8865 - val_loss: 0.3532 - learning_rate: 3.1250e-05
# Epoch 43/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.9064 - loss: 0.2867 - val_accuracy: 0.8860 - val_loss: 0.3598 - learning_rate: 3.1250e-05
# Epoch 44/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.9056 - loss: 0.2860 - val_accuracy: 0.8898 - val_loss: 0.3532 - learning_rate: 3.1250e-05
# Epoch 45/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.9020 - loss: 0.2922 - val_accuracy: 0.8862 - val_loss: 0.3591 - learning_rate: 3.1250e-05
# Epoch 46/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 10ms/step - accuracy: 0.9080 - loss: 0.2763 - val_accuracy: 0.8893 - val_loss: 0.3518 - learning_rate: 1.5625e-05
# Epoch 47/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.9078 - loss: 0.2786 - val_accuracy: 0.8891 - val_loss: 0.3527 - learning_rate: 1.5625e-05
# Epoch 48/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - accuracy: 0.9088 - loss: 0.2781 - val_accuracy: 0.8883 - val_loss: 0.3502 - learning_rate: 1.5625e-05
# Epoch 49/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0.9108 - loss: 0.2750 - val_accuracy: 0.8874 - val_loss: 0.3507 - learning_rate: 1.5625e-05
# Epoch 50/50
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.9090 - loss: 0.2744 - val_accuracy: 0.8885 - val_loss: 0.3509 - learning_rate: 1.5625e-05
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8864 - loss: 0.3539
# Test accuracy: 0.8883000016212463
# Test loss: 0.35023677349090576

# %% [markdown]
# Висновок
# Друга модель з Keras Tuner має меншу точність (88.87%) в порівнянні з першою моделлю (89.76%).
